# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/3f/2e/b1a64cfb43d008f34ac4b6cf5ff137b2ed2e3e049977037d09ff68568101/pymongo-4.7.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading pymongo-4.7.3-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.7.3-cp312-cp312-win_amd64.whl (484 kB)
#    ---------------------------------------- 0.0/484.2 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/484.2 kB ? eta -:--:--
#    ---------- ----------------------------- 122.9/484.2 kB 2.4 MB/s eta 0:00:01
#    ------------------ --------------------- 225.3/484.2 kB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 317.4/484.2 kB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 450.6/484.2 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 484.2/484.2 kB 2.2 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    ------------------------- -------------- 194.6/307.7 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  307.2/307.7 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 307.7/307.7 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.3
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client.test
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test')

# %%
db = client['Airbnb']
col = db['Sample']

# %%
col
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Airbnb'), 'Sample')

# %%
for i in col.find():
    print(i)
    break
# Out:
# {'_id': '1003530', 'listing_url': 'https://www.airbnb.com/rooms/1003530', 'name': 'New York City - Upper West Side Apt', 'summary': '', 'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.', 'description': "Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement. New York City! Great neighborhood - many terrific restaurants, bakeries, bagelries. Within easy walking distance are restaurants with the cuisines from India, Thailand, Japan, China, Mexico, South America and Europe.  As well as the many small independent stores that line Broadway, there chain stores such as Urban Outfitters (clothing), Whole Foods (groceries), Sephora (cosmetics), Michaels (crafts), and Modell's (sporting goods). Equidistant to Central Park and Riverside Park which have walking/running/biking trails as well as tennis and racquet ball courts. 10-15 blocks from Columbia University between Broadway and Amsterdam. The International Hostel across the street is an airport shuttle bus and double-decker tour bus stop.  The Hostel also has services available to the neighborhood such as lectures, brochures, etc. Convenientl", 'neighborhood_overview': "Great neighborhood - many terrific restaurants, bakeries, bagelries. Within easy walking distance are restaurants with the cuisines from India, Thailand, Japan, China, Mexico, South America and Europe.  As well as the many small independent stores that line Broadway, there chain stores such as Urban Outfitters (clothing), Whole Foods (groceries), Sephora (cosmetics), Michaels (crafts), and Modell's (sporting goods). Equidistant to Central Park and Riverside Park which have walking/running/biking trails as well as tennis and racquet ball courts. 10-15 blocks from Columbia University between Broadway and Amsterdam. The International Hostel across the street is an airport shuttle bus and double-decker tour bus stop.  The Hostel also has services available to the neighborhood such as lectures, brochures, etc.", 'notes': 'My cat, Samantha, are in and out during the summer.  The apt is layed out in such a  way that each bedroom is very private.', 'transit': 'Conveniently located near 1, 2, 3, B & C subway lines. Also buses on Columbus Avenue (downtown), Amsterdam Avenue (uptown), and Broadway (uptown/downtown). Also near origination/termination of M60 bus which goes to/from LaGuardia Airport.', 'access': 'New York City!', 'interaction': '', 'house_rules': 'No smoking is permitted in the apartment. All towels that are used should be placed in the bath tub upon departure. I have a cat, Samantha, who can stay or go, whichever is preferred.   Please text me upon departure.', 'property_type': 'Apartment', 'room_type': 'Private room', 'bed_type': 'Real Bed', 'minimum_nights': '12', 'maximum_nights': '360', 'cancellation_policy': 'strict_14_with_grace_period', 'last_scraped': '2019-03-07 05:00:00', 'calendar_last_scraped': '2019-03-07 05:00:00', 'first_review': '2013-04-29 04:00:00', 'last_review': '2018-08-12 04:00:00', 'accommodates': 2, 'bedrooms': 1, 'beds': 1, 'number_of_reviews': 70, 'bathrooms': 1, 'amenities': ['Internet', 'Wifi', 'Air conditioning', 'Kitchen', 'Elevator', 'Buzzer/wireless intercom', 'Heating', 'Family/kid friendly', 'Washer', 'Dryer', 'translation missing: en.hosting_amenity_50'], 'price': 135, 'security_deposit': 0, 'cleaning_fee': 135, 'extra_people': 0, 'guests_included': 1, 'images': {'thumbnail_url': '', 'medium_url': '', 'picture_url': 'https://a0.muscache.com/im/pictures/15074036/a97119ed_original.jpg?aki_policy=large', 'xl_picture_url': ''}, 'host': {'host_id': '454250', 'host_url': 'https://www.airbnb.com/users/show/454250', 'host_name': 'Greta', 'host_location': 'New York, New York, United States', 'host_about': 'By now I have lived longer in the city than the country however I fe ...

# %%
data=[]
for i in col.find():
    data.append(i)
print(data)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data[5554]
# Out:
# {'_id': '9936016',
#  'listing_url': 'https://www.airbnb.com/rooms/9936016',
#  'name': 'Alugo Apartamento na Tijuca',
#  'summary': 'Apartamento amplo que acomoda 6 pessoas. Um quarto com sofá cama de casal com armários, ventilador de teto e ar-condicionado. Sala com um sofá cama de casal, com ventilador de teto e climatizador. Dois banheiros, cozinha completa e área.',
#  'space': '',
#  'description': 'Apartamento amplo que acomoda 6 pessoas. Um quarto com sofá cama de casal com armários, ventilador de teto e ar-condicionado. Sala com um sofá cama de casal, com ventilador de teto e climatizador. Dois banheiros, cozinha completa e área.',
#  'neighborhood_overview': '',
#  'notes': '',
#  'transit': '',
#  'access': '',
#  'interaction': '',
#  'house_rules': 'Cuidar das instalações e objetos da casa em perfeito estado',
#  'property_type': 'Apartment',
#  'room_type': 'Entire home/apt',
#  'bed_type': 'Real Bed',
#  'minimum_nights': '1',
#  'maximum_nights': '1125',
#  'cancellation_policy': 'flexible',
#  'last_scraped': '2019-02-11 05:00:00',
#  'calendar_last_scraped': '2019-02-11 05:00:00',
#  'accommodates': 6,
#  'bedrooms': 1,
#  'beds': 2,
#  'number_of_reviews': 0,
#  'bathrooms': 2,
#  'amenities': ['TV',
#   'Cable TV',
#   'Internet',
#   'Wifi',
#   'Air conditioning',
#   'Kitchen',
#   'Pets allowed',
#   'Pets live on this property',
#   'Dog(s)',
#   'Buzzer/wireless intercom',
#   'Family/kid friendly',
#   'Washer',
#   'Hangers',
#   'Iron'],
#  'price': 750,
#  'extra_people': 0,
#  'guests_included': 1,
#  'images': {'thumbnail_url': '',
#   'medium_url': '',
#   'picture_url': 'https://a0.muscache.com/im/pictures/9d939095-fb2a-4bf8-8c46-5c73c2969974.jpg?aki_policy=large',
#   'xl_picture_url': ''},
#  'host': {'host_id': '47092481',
#   'host_url': 'https://www.airbnb.com/users/show/47092481',
#   'host_name': 'Aliane',
#   'host_location': 'BR',
#   'host_about': '',
#   'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/4b17fc8e-44c0-487a-8cdb-a56a53c44384.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a0.muscache.com/im/pictures/4b17fc8e-44c0-487a-8cdb-a56a53c44384.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': '',
#   'host_is_superhost': False,
#   'host_has_profile_pic': True,
#   'host_identity_verified': False,
#   'host_listings_count': 1,
#   'host_total_listings_count': 1,
#   'host_verifications': ['phone']},
#  'address': {'street': 'Rio de Janeiro, Rio de Janeiro, Brazil',
#   'suburb': 'Lapa',
#   'government_area': 'Centro',
#   'market': 'Rio De Janeiro',
#   'country': 'Brazil',
#   'country_code': 'BR',
#   'location': {'type': 'Point',
#    'coordinates': [-43.173761316748546, -22.90833634089244],
#    'is_location_exact': False}},
#  'availability': {'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 0},
#  'review_scores': {},
#  'reviews': []}

# %%
import pandas as pd

# Convert MongoDB cursor to DataFrame
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (5555, 42)

# %%
df.head(3)
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
#
#                                   name  \
# 0  New York City - Upper West Side Apt
# 1  Double and triple rooms Blue mosque
# 2   Soho Cozy, Spacious and Convenient
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# 1  We are on the central city  Blue mosque 5 minu...
# 2
#
#                                          description  \
# 0  Murphy bed, optional second bedroom available....
# 1  We are on the central city  Blue mosque 5 minu...
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
#
#                                neighborhood_overview  \
# 0  Great neighborhood - many terrific restaurants...
# 1  Cankurtaran mahallesi akbıyık caddesi no 22 Su...
# 2
#
#                                                notes  \
# 0  My cat, Samantha, are in and out during the su...
# 1
# 2
#
#                                              transit  \
# 0  Conveniently located near 1, 2, 3, B & C subwa...
# 1   Tram 5 minutes  metro 10 minutes  Bus 10 minutes
# 2
#
#                                               access  ... guests_included  \
# 0                                     New York City!  ...               1
# 1  We have bathroom,wc,İnternet in rooms and unde...  ...               1
# 2                                                     ...               1
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '454250', 'host_url': 'https://www...
# 1  {'host_id': '52004703', 'host_url': 'https://w...
# 2  {'host_id': '51624384', 'host_url': 'https://w...
#
#                                              address  \
# 0  {'street': 'New York, NY, United States', 'sub...
# 1  {'street': 'Fatih , İstanbul, Turkey', 'suburb...
# 2  {'street': 'Hong Kong, Hong Kong Island, Hong ...
#
#                                         availability  \
# 0  {'availability_30': 0, 'availability_60': 0, '...
# 1  {'availability_30': 30, 'availability_60': 60,...
# 2  {'availability_30': 0, 'availability_60': 0, '...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 10, 'review_scores_...
# 1  {'review_scores_accuracy': 9, 'review_scores_c...
# 2  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                              reviews weekly_price  \
# 0  [{'_id': '4351675', 'date': '2013-04-29 04:00:...          NaN
# 1  [{'_id': '149469150', 'date': '2017-05-04 04:0...          NaN
# 2  [{'_id': '56904633', 'date': '2015-12-19 05:00...       5000.0
#
#   monthly_price reviews_per_month
# 0           NaN               NaN
# 1           NaN               NaN
# 2           NaN               NaN
#
# [3 rows x 42 columns]

# %%
df.describe()
# Out:
#        accommodates     bedrooms         beds  number_of_reviews    bathrooms  \
# count   5555.000000  5550.000000  5542.000000        5555.000000  5545.000000
# mean       3.505851     1.411712     2.071454          27.606481     1.291163
# std        2.297019     1.041942     1.619660          49.798376     0.702265
# min        1.000000     0.000000     0.000000           0.000000     0.000000
# 25%        2.000000     1.000000     1.000000           1.000000     1.000000
# 50%        3.000000     1.000000     2.000000           5.000000     1.000000
# 75%        4.000000     2.000000     3.000000          32.000000     1.000000
# max       16.000000    20.000000    25.000000         533.000000    16.000000
#
#               price  security_deposit  cleaning_fee  extra_people  \
# count   5555.000000       3471.000000   4024.000000   5555.000000
# mean     278.766157        509.430424     94.074801     22.791899
# std      842.215531       1594.805320    110.203782     69.331511
# min        9.000000          0.000000      0.000000      0.000000
# 25%       70.000000          0.000000     23.000000      0.000000
# 50%      129.000000        200.000000     60.000000      0.000000
# 75%      280.000000        500.000000    129.000000     20.000000
# max    48842.000000      39228.000000   2000.000000   2346.000000
#
#        guests_included  weekly_price  monthly_price  reviews_per_month
# count      5555.000000    714.000000     656.000000          94.000000
# mean          1.747435   1530.903361    5391.370427           1.712766
# std           1.487352   3185.916331   12723.569651           1.492795
# min           1.000000     60.000000     250.000000           1.000000
# 25%           1.000000    480.250000    1505.250000           1.000000
# 50%           1.000000    800.000000    2800.000000           1.000000
# 75%           2.000000   1575.250000    4800.000000           2.000000
# max          16.000000  59123.000000  253384.000000          10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    5555 non-null   object
#  1   listing_url            5555 non-null   object
#  2   name                   5555 non-null   object
#  3   summary                5555 non-null   object
#  4   space                  5555 non-null   object
#  5   description            5555 non-null   object
#  6   neighborhood_overview  5555 non-null   object
#  7   notes                  5555 non-null   object
#  8   transit                5555 non-null   object
#  9   access                 5555 non-null   object
#  10  interaction            5555 non-null   object
#  11  house_rules            5555 non-null   object
#  12  property_type          5555 non-null   object
#  13  room_type              5555 non-null   object
#  14  bed_type               5555 non-null   object
#  15  minimum_nights         5555 non-null   object
#  16  maximum_nights         5555 non-null   object
#  17  cancellation_policy    5555 non-null   object
#  18  last_scraped           5555 non-null   object
#  19  calendar_last_scraped  5555 non-null   object
#  20  first_review           4167 non-null   object
#  21  last_review            4167 non-null   object
#  22  accommodates           5555 non-null   int64
#  23  bedrooms               5550 non-null   float64
#  24  beds                   5542 non-null   float64
#  25  number_of_reviews      5555 non-null   int64
#  26  bathrooms              5545 non-null   float64
#  27  amenities              5555 non-null   object
#  28  price                  5555 non-null   int64
#  29  security_deposit       3471 non-null   float64
#  30  cleaning_fee           4024 non-null   float64
#  31  extra_people           5555 non-null   int64
#  32  guests_included        5555 non-null   int64
#  33  images                 5555 non-null   object
#  34  host                   5555 non-null   object
#  35  address                5555 non-null   object
#  36  availability           5555 non-null   object
#  37  review_scores          5555 non-null   object
#  38  reviews                5555 non-null   object
#  39  weekly_price           714 non-null    float64
#  40  monthly_price          656 non-null    float64
#  41  reviews_per_month      94 non-null     float64
# dtypes: float64(8), int64(5), object(29)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# extra_people                0
# guests_included             0
# images                      0
# host                        0
# address                     0
# availability                0
# review_scores               0
# reviews                     0
# weekly_price             4841
# monthly_price            4899
# reviews_per_month        5461
# dtype: int64

# %%
data = df.drop(['_id','listing_url','summary','name','space','description','neighborhood_overview','notes','transit','access','interaction','house_rules','amenities', 'images', 'host', 'address', 'availability', 'review_scores', 'reviews','reviews_per_month','monthly_price','weekly_price','first_review','last_review','cleaning_fee','security_deposit'], axis = 'columns')

# %%
data.head(10)
# Out:
#        property_type        room_type  bed_type minimum_nights maximum_nights  \
# 0          Apartment     Private room  Real Bed             12            360
# 1  Bed and breakfast     Private room  Real Bed              1           1125
# 2          Apartment  Entire home/apt  Real Bed              4             20
# 3         Guesthouse     Private room     Futon              1            500
# 4          Apartment  Entire home/apt  Real Bed             10             21
# 5             Hostel     Private room  Real Bed              1           1125
# 6          Apartment  Entire home/apt  Real Bed              2           1125
# 7          Apartment     Private room  Real Bed              1             10
# 8          Apartment     Private room  Real Bed             14           1125
# 9          Apartment  Entire home/apt  Real Bed              3             75
#
#            cancellation_policy         last_scraped calendar_last_scraped  \
# 0  strict_14_with_grace_period  2019-03-07 05:00:00   2019-03-07 05:00:00
# 1                     moderate  2019-02-18 05:00:00   2019-02-18 05:00:00
# 2                     flexible  2019-03-11 04:00:00   2019-03-11 04:00:00
# 3  strict_14_with_grace_period  2019-03-11 04:00:00   2019-03-11 04:00:00
# 4  strict_14_with_grace_period  2019-03-07 05:00:00   2019-03-07 05:00:00
# 5                     moderate  2019-02-16 05:00:00   2019-02-16 05:00:00
# 6                     flexible  2019-03-06 05:00:00   2019-03-06 05:00:00
# 7  strict_14_with_grace_period  2019-03-07 05:00:00   2019-03-07 05:00:00
# 8                     flexible  2019-03-06 05:00:00   2019-03-06 05:00:00
# 9  strict_14_with_grace_period  2019-02-11 05:00:00   2019-02-11 05:00:00
#
#    accommodates  bedrooms  beds  number_of_reviews  bathrooms  price  \
# 0             2       1.0   1.0                 70        1.0    135
# 1             3       1.0   2.0                 29        1.0    121
# 2             3       1.0   2.0                  3        1.0    699
# 3             1       1.0   1.0                 81        1.0    181
# 4             2       0.0   1.0                 64        1.0    181
# 5             2       1.0   1.0                  0        1.0     40
# 6             2       1.0   1.0                  1        1.0    145
# 7             2       1.0   1.0                239        1.0     45
# 8             1       1.0   1.0                  1        1.5     40
# 9             4       1.0   3.0                 70        2.0    119
#
#    extra_people  guests_included
# 0             0                1
# 1             0                1
# 2             0                1
# 3           100                1
# 4             0                1
# 5            25                2
# 6             0                1
# 7            10                1
# 8             0                1
# 9            40                3

# %%
data.isnull().sum()
# Out:
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# last_scraped              0
# calendar_last_scraped     0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# extra_people              0
# guests_included           0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# property_type            0
# room_type                0
# bed_type                 0
# minimum_nights           0
# maximum_nights           0
# cancellation_policy      0
# last_scraped             0
# calendar_last_scraped    0
# accommodates             0
# bedrooms                 0
# beds                     0
# number_of_reviews        0
# bathrooms                0
# price                    0
# extra_people             0
# guests_included          0
# dtype: int64

# %%
data.shape
# Out:
# (5532, 16)

# %%
data.to_csv('Airbnb.csv', index = True)
